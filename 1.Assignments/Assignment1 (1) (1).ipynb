# %%
#creating a dataframe with 4 features and 4 observations
import pandas as pd
import numpy as np
data=np.random.randn(4,4)
df=pd.DataFrame(data,columns=["col1","col2","col3","col4"])
df
# Out:
#        col1      col2      col3      col4
# 0  0.031922 -0.419791 -0.784030  0.899372
# 1  0.086381  0.910650 -1.300342 -1.401238
# 2 -2.263063 -0.862106 -0.824740 -2.027512
# 3 -0.605582  0.241718  0.223093 -0.754830

# %%
df.columns =['randomvalue1','randomvalue2','randomvalue3','randomvalue4']
df
# Out:
#    randomvalue1  randomvalue2  randomvalue3  randomvalue4
# 0      0.031922     -0.419791     -0.784030      0.899372
# 1      0.086381      0.910650     -1.300342     -1.401238
# 2     -2.263063     -0.862106     -0.824740     -2.027512
# 3     -0.605582      0.241718      0.223093     -0.754830

# %%
df.describe()
# Out:
#        randomvalue1  randomvalue2  randomvalue3  randomvalue4
# count      4.000000      4.000000      4.000000      4.000000
# mean      -0.687585     -0.032382     -0.671505     -0.821052
# std        1.096292      0.775235      0.640803      1.259154
# min       -2.263063     -0.862106     -1.300342     -2.027512
# 25%       -1.019952     -0.530370     -0.943640     -1.557806
# 50%       -0.286830     -0.089036     -0.804385     -1.078034
# 75%        0.045537      0.408951     -0.532249     -0.341280
# max        0.086381      0.910650      0.223093      0.899372

# %%
df.isnull().any()
# Out:
# randomvalue1    False
# randomvalue2    False
# randomvalue3    False
# randomvalue4    False
# dtype: bool

# %%
#location method
df.loc[ : , 'randomvalue2':'randomvalue3']
# Out:
#    randomvalue2  randomvalue3
# 0     -0.419791     -0.784030
# 1      0.910650     -1.300342
# 2     -0.862106     -0.824740
# 3      0.241718      0.223093

# %%
#ilocation method
df.iloc[ : , 1:3]
# Out:
#    randomvalue2  randomvalue3
# 0     -0.419791     -0.784030
# 1      0.910650     -1.300342
# 2     -0.862106     -0.824740
# 3      0.241718      0.223093
